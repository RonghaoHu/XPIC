# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
field = np.loadtxt('fields.txt')
particle = np.loadtxt('particles.txt')

# %%
plt.plot(field[:,0])

# %%
plt.plot(field[:,2])

# %%
plt.plot(field[:,3])

# %%
particle.shape
# Out:
# (64000, 4)

# %%
plt.scatter(particle[:,0],particle[:,1],s=0.01)
