# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
field = np.loadtxt('fields_29.dat')
particle = np.loadtxt('particles_29.dat')

# %%
plt.plot(field[:,0],field[:,1])

# %%
plt.figure(dpi=300)
plt.plot(field[:,0],field[:,3])
#plt.xlim((200,300))

# %%
plt.plot(field[:,0],field[:,4])

# %%
particle.shape
# Out:
# (64000, 4)

# %%
plt.scatter(particle[:,0],particle[:,1],s=0.001)
#plt.xlim((120,140))
