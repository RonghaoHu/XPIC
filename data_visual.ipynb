# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_id = h5.File('data_28.h5','r')
fdata=file_id['density']
density=fdata.__array__()
fdata=file_id['ex']
ex=fdata.__array__()
fdata=file_id['ey']
ey=fdata.__array__()
fdata=file_id['bz']
bz=fdata.__array__()
fdata=file_id['jx']
jx=fdata.__array__()
fdata=file_id['jy']
jy=fdata.__array__()
fdata=file_id['particle']
part=fdata.__array__()
part.resize((int(part.size/5),5))

# %%
plt.figure(dpi=300)
plt.plot(ey)

# %%
plt.figure(dpi=300)
plt.plot(ex)
#plt.xlim((200,300))

# %%
plt.figure(dpi=300)
plt.plot(density)

# %%
plt.figure(dpi=300)
#plt.plot(ey*10)
plt.plot(jy)
plt.xlim((12000,13000))
#plt.ylim((-1,1))
# Out:
# (12000.0, 13000.0)

# %%
plt.figure(dpi=300)
plt.scatter(part[:,0],part[:,1],s=0.001)
#plt.xlim((120,140))
